# %% [markdown]
# # else가 없는 조건문
#
# ```
# if 조건식:
#     조건식이 참일 때 실행할 코드(블록)
# ```
#
# * `if 조건식` 뒤에는 반드시 콜론(:)을 사용해야 함
# * `if` 블록(조건식이 참일 때 실행하는 문장들)은 반드시 __같은 크기로__ 들여쓰기(indentation)를 해야 함
# *  **별표 두 개는 bold**    __밑줄 두 개도 bold__     _밑줄하나는 기울임_

# %%
n = 100

# %%
if n > 0 :
    print('양수')
    print('if 블록 끝')

print('if 바깥')
# Out:
# 양수
# if 블록 끝
# if 바깥

# %% [markdown]
# # else가 있는 조건문
#
# ```
# if 조건식 :
#     조건식이 참일 때 실행할 코드 블록
# else :
#     조건식이 거짓일 때 실행할 코드 블록
# ```

# %%
n = int(input('정수 입력>>> '))
if n % 2 :   # 2로 나눈 나머지가 있으면 = 0이 아니면( = true)
    print('홀수')   # (1)
else :  # 2로 나눈 나머지가 없으면 = 0이면( = false)
    print('짝수')   # (2)
# Out:
# 정수 입력>>> -12
# 짝수

# %% [markdown]
# Python에서 참(True)으로 취급하는 것들:
#
# * 0이 아닌 숫자들  (0은 false)
# * 1개 이상의 글자를 가지고 있는 문자열
# * 1개 이상의 원소를 가지고 있는 리스트, ...

# %% [markdown]
# # chained conditional
#
# ```
# if 조건식1 :
#     조건식1이 참일 때 실행할 코드 블록
# elif 조건식2 :
#     조건식2가 참일 때 실행할 코드 블록
# ...
# else :    (필수는 아님)
#     위의 모든 조건식들을 만족하지 못할 때 실행할 코드 블록
#
# ```

# %%
x = int(input('정수 입력>>> '))
y = int(input('정수 입력>>> '))
z = int(input('정수 입력>>> '))

avg = (x + y + z) / 3
print(f'평균 = {avg}점')

if avg >= 90 :
    print('A')
elif avg >= 80 :
    print('B')
elif avg >= 70 :
    print('C')
else :
    print('F')
# Out:
# 정수 입력>>> 36
# 정수 입력>>> 8
# 정수 입력>>> 76
# 평균 = 40.0점
# F
